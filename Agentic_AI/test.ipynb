# %% [markdown]
# ## Stardog Database Connection Setup
#  - Import required libraries (os, dotenv, stardog)
#  - Load environment variables for Stardog credentials
#  - Define StardogClient class for database connection and queries
#  - Implement query and update methods with error handling

# %%
import os
from dotenv import load_dotenv
import stardog

load_dotenv()

# Stardog configuration
STARDOG_ENDPOINT = os.getenv("STARDOG_ENDPOINT")
STARDOG_DATABASE = os.getenv("STARDOG_DATABASE")
STARDOG_USERNAME = os.getenv("STARDOG_USERNAME")
STARDOG_PASSWORD = os.getenv("STARDOG_PASSWORD")

class StardogClient:
    def __init__(self, endpoint, database, username, password):
        self.endpoint = endpoint
        self.database = database
        self.connection_details = {
            'endpoint': endpoint,
            'username': username,
            'password': password
        }
        self.database = database

    def query(self, sparql_query, use_reasoning=True):
        """Execute a SPARQL query against Stardog"""
        try:
            with stardog.Connection(self.database, **self.connection_details) as conn:
                # Execute the query with reasoning if enabled
                result = conn.select(sparql_query, reasoning=use_reasoning)
                return result
        except Exception as e:
            print(f"Error executing SPARQL query: {e}")
            return None

    def update(self, sparql_update):
        """Execute a SPARQL UPDATE query"""
        try:
            with stardog.Connection(self.database, **self.connection_details) as conn:
                conn.begin()
                conn.update(sparql_update)
                conn.commit()
                return True
        except Exception as e:
            print(f"Error executing SPARQL update: {e}")
            return False

    def get_schema(self):
        """Get the ontology schema from the knowledge graph, including classes, properties, and their domains and ranges."""
        schema_details_query = """
        SELECT ?s ?p ?o
        FROM <tag:stardog:api:context:schema>
        WHERE {
            # ?s ?p ?o
        }
        """
        schema_result = self.query(schema_details_query, use_reasoning=False)
        if schema_result and schema_result.get('results', {}).get('bindings'):
            triples = schema_result['results']['bindings']

            classes = set()
            object_properties = {}
            datatype_properties = {}

            ontology_base = 'https://a.in/sales/ontology#'
            def short_name(uri):
                return uri[len(ontology_base):] if uri.startswith(ontology_base) else uri

            for triple in triples:
                subject = triple['s']['value']
                predicate = triple['p']['value']
                obj = triple['o']['value']

                # Identify classes
                if predicate == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type':
                    if obj == 'http://www.w3.org/2002/07/owl#Class':
                        cls = short_name(subject)
                        if cls != 'https://a.in/sales/ontology':
                            classes.add(cls)
                    elif obj == 'http://www.w3.org/2002/07/owl#ObjectProperty':
                        op = short_name(subject)
                        if op not in object_properties:
                            object_properties[op] = {'domain': None, 'range': None}
                    elif obj == 'http://www.w3.org/2002/07/owl#DatatypeProperty':
                        dp = short_name(subject)
                        if dp not in datatype_properties:
                            datatype_properties[dp] = {'domain': None, 'range': None}

                # Identify domain/range
                if predicate == 'http://www.w3.org/2000/01/rdf-schema#domain':
                    prop = short_name(subject)
                    val = short_name(obj)
                    if prop in object_properties:
                        object_properties[prop]['domain'] = val
                    elif prop in datatype_properties:
                        datatype_properties[prop]['domain'] = val
                if predicate == 'http://www.w3.org/2000/01/rdf-schema#range':
                    prop = short_name(subject)
                    val = short_name(obj)
                    if prop in object_properties:
                        object_properties[prop]['range'] = val
                    elif prop in datatype_properties:
                        datatype_properties[prop]['range'] = val

            return {
                'classes': sorted(classes),
                'object_properties': object_properties,
                'datatype_properties': datatype_properties,
                'raw_result': schema_result
            }
        return None

# Initialize Stardog client
stardog_client = StardogClient(STARDOG_ENDPOINT, STARDOG_DATABASE, STARDOG_USERNAME, STARDOG_PASSWORD)

# Sample ontology prefixes for e-commerce domain
PREFIXES = """
PREFIX ex: <https://a.in/sales/ontology#>
PREFIX data: <https://a.in/sales/data#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX schema: <http://schema.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
"""

print("Stardog KG client initialized successfully!")
# Out:
# Stardog KG client initialized successfully!

# %% [markdown]
# ## Schema Exploration
# - Initializing Stardog client to connect to the knowledge graph
# - Retrieving and displaying the schema information including:
#   - Classes (Product, Customer, Order etc.)
#   - Object properties (relationships between classes)
#   - Datatype properties (attributes of classes)
# - Helps understand the structure and organization of the e-commerce ontology

# %%
stardog_client = StardogClient(STARDOG_ENDPOINT, STARDOG_DATABASE, STARDOG_USERNAME, STARDOG_PASSWORD)
print("Stardog database:", STARDOG_DATABASE)
display(stardog_client.get_schema())
# Out:
# Stardog endpoint: https://sd-682b640b.stardog.cloud:5820
# Stardog database: Sales_360
# Stardog username: testing
# Stardog password: KnowledgeGraph
# {'classes': ['https://sales.org/sales/ontology#Customer',
#   'https://sales.org/sales/ontology#CustomerAddress',
#   'https://sales.org/sales/ontology#CustomerContact',
#   'https://sales.org/sales/ontology#Inventory',
#   'https://sales.org/sales/ontology#Order',
#   'https://sales.org/sales/ontology#Product',
#   'https://sales.org/sales/ontology#ProductBrand',
#   'https://sales.org/sales/ontology#ProductClass',
#   'https://sales.org/sales/ontology#ProductDetail',
#   'https://sales.org/sales/ontology#ProductFamily',
#   'https://sales.org/sales/ontology#ProductLine',
#   'https://sales.org/sales/ontology#ProductType',
#   'https://sales.org/sales/ontology#Sale',
#   'https://sales.org/sales/ontology#SalesDiscountTax',
#   'https://sales.org/sales/ontology#SalesFulfillment',
#   'https://sales.org/sales/ontology#SalesPayment',
#   'https://sales.org/sales/ontology#Supplier'],
#  'object_properties': {'https://sales.org/sales/ontology#hasContact': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'https://sales.org/sales/ontology#CustomerContact'},
#   'https://sales.org/sales/ontology#isContactOf': {'domain': 'https://sales.org/sales/ontology#CustomerContact',
#    'range': 'https://sales.org/sales/ontology#Customer'},
#   'https://sales.org/sales/ontology#hasAddress': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'https://sales.org/sales/ontology#CustomerAddress'},
#   'https://sales.org/sales/ontology#isAddressOf': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'https://sales.org/sales/ontology#Customer'},
#   'https://sales.org/sales/ontology#hasOrder': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'https://sales.org/sales/ontology#Order'},
#   'https://sales.org/sales/ontology#orderedBy': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'https://sales.org/sales/ontology#Customer'},
#   'https://sales.org/sales/ontology#hasSale': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'https://sales.org/sales/ontology#Sale'},
#   'https://sales.org/sales/ontology#saleFromOrder': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'https://sales.org/sales/ontology#Order'},
#   'https://sales.org/sales/ontology#hasPayment': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'https://sales.org/sales/ontology#SalesPayment'},
#   'https://sales.org/sales/ontology#isPaymentFor': {'domain': 'https://sales.org/sales/ontology#SalesPayment',
#    'range': 'https://sales.org/sales/ontology#Sale'},
#   'https://sales.org/sales/ontology#hasDiscountDetail': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'https://sales.org/sales/ontology#SalesDiscountTax'},
#   'https://sales.org/sales/ontology#isDiscountOf': {'domain': 'https://sales.org/sales/ontology#SalesDiscountTax',
#    'range': 'https://sales.org/sales/ontology#Sale'},
#   'https://sales.org/sales/ontology#hasFulfillment': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'https://sales.org/sales/ontology#SalesFulfillment'},
#   'https://sales.org/sales/ontology#isFulfillmentFor': {'domain': 'https://sales.org/sales/ontology#SalesFulfillment',
#    'range': 'https://sales.org/sales/ontology#Sale'},
#   'https://sales.org/sales/ontology#hasInventory': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#Inventory'},
#   'https://sales.org/sales/ontology#isInventoryOf': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#orderedProduct': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#productOrderedIn': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#Order'},
#   'https://sales.org/sales/ontology#hasDetail': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#ProductDetail'},
#   'https://sales.org/sales/ontology#isDetailOf': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#hasBrand': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#ProductBrand'},
#   'https://sales.org/sales/ontology#isBrandOf': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#hasType': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#ProductType'},
#   'https://sales.org/sales/ontology#isTypeOf': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#hasLine': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#ProductLine'},
#   'https://sales.org/sales/ontology#isLineOf': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#hasClass': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#ProductClass'},
#   'https://sales.org/sales/ontology#isClassOf': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#hasFamily': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#ProductFamily'},
#   'https://sales.org/sales/ontology#isFamilyOf': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'https://sales.org/sales/ontology#Product'},
#   'https://sales.org/sales/ontology#hasSupplier': {'domain': 'https://sales.org/sales/ontology#Product',
#    'range': 'https://sales.org/sales/ontology#Supplier'},
#   'https://sales.org/sales/ontology#isSupplierFor': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'https://sales.org/sales/ontology#Product'}},
#  'datatype_properties': {'https://sales.org/sales/ontology#gender': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#age': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#email': {'domain': 'https://sales.org/sales/ontology#CustomerContact',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#phone': {'domain': 'https://sales.org/sales/ontology#CustomerContact',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#address': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#city': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#state': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#country': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#customerId': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#contactId': {'domain': 'https://sales.org/sales/ontology#CustomerContact',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#addressId': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#orderId': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#saleId': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#inventoryId': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#supplierId': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#brandId': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#typeId': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#lineId': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#classId': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#familyId': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#skuId': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#customerName': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#registrationDate': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'http://www.w3.org/2001/XMLSchema#date'},
#   'https://sales.org/sales/ontology#isActive': {'domain': 'https://sales.org/sales/ontology#Customer',
#    'range': 'http://www.w3.org/2001/XMLSchema#boolean'},
#   'https://sales.org/sales/ontology#addressType': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#postalCode': {'domain': 'https://sales.org/sales/ontology#CustomerAddress',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#orderDate': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'http://www.w3.org/2001/XMLSchema#date'},
#   'https://sales.org/sales/ontology#orderStatus': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#quantity': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#price': {'domain': 'https://sales.org/sales/ontology#Order',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#totalAmount': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#saleDate': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'http://www.w3.org/2001/XMLSchema#date'},
#   'https://sales.org/sales/ontology#netAmount': {'domain': 'https://sales.org/sales/ontology#Sale',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#paymentMethod': {'domain': 'https://sales.org/sales/ontology#SalesPayment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#paymentStatus': {'domain': 'https://sales.org/sales/ontology#SalesPayment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#invoiceNumber': {'domain': 'https://sales.org/sales/ontology#SalesPayment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#transactionId': {'domain': 'https://sales.org/sales/ontology#SalesPayment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#discountValue': {'domain': 'https://sales.org/sales/ontology#SalesDiscountTax',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#discountPercent': {'domain': 'https://sales.org/sales/ontology#SalesDiscountTax',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#taxAmount': {'domain': 'https://sales.org/sales/ontology#SalesDiscountTax',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#shippingCharges': {'domain': 'https://sales.org/sales/ontology#SalesDiscountTax',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#fulfillmentStatus': {'domain': 'https://sales.org/sales/ontology#SalesFulfillment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#returnReason': {'domain': 'https://sales.org/sales/ontology#SalesFulfillment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#refundStatus': {'domain': 'https://sales.org/sales/ontology#SalesFulfillment',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#location': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#quantityOnHand': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#reorderLevel': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#reorderQuantity': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#safetyStockLevel': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#lastRestockDate': {'domain': 'https://sales.org/sales/ontology#Inventory',
#    'range': 'http://www.w3.org/2001/XMLSchema#date'},
#   'https://sales.org/sales/ontology#supplierName': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#contactName': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#supplierEmail': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#supplierPhone': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#supplierAddress': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#supplierCountry': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#leadTimeDays': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#int'},
#   'https://sales.org/sales/ontology#supplierRating': {'domain': 'https://sales.org/sales/ontology#Supplier',
#    'range': 'http://www.w3.org/2001/XMLSchema#float'},
#   'https://sales.org/sales/ontology#skuName': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#upc': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#unitOfMeasure': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#packSize': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#packType': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#pricing': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#decimal'},
#   'https://sales.org/sales/ontology#netWeight': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#taxCode': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#shelfLife': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#ingredientsList': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#seoKeywords': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#availability': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#activeStatus': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#boolean'},
#   'https://sales.org/sales/ontology#regulatoryLabeling': {'domain': 'https://sales.org/sales/ontology#ProductDetail',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#brandName': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#subBrandName': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#manufacturer': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#tagline': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#trademarkStatus': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#marketingPositioning': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#isPromotional': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#boolean'},
#   'https://sales.org/sales/ontology#brandStatus': {'domain': 'https://sales.org/sales/ontology#ProductBrand',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#typeName': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#variant': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#format': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#claims': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#usageOccasion': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#nutritionalHighlights': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#regulatoryTag': {'domain': 'https://sales.org/sales/ontology#ProductType',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#lineName': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#targetAudience': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#functionalUse': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#channelRelevance': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#launchRegion': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#launchDate': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#date'},
#   'https://sales.org/sales/ontology#productForm': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#packagingFormats': {'domain': 'https://sales.org/sales/ontology#ProductLine',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#className': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#categoryCode': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#consumerSegment': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#seasonality': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#shelfStrategy': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#forecastGroup': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#isTaxable': {'domain': 'https://sales.org/sales/ontology#ProductClass',
#    'range': 'http://www.w3.org/2001/XMLSchema#boolean'},
#   'https://sales.org/sales/ontology#familyName': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#department': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#businessUnit': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#region': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#familyStatus': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'},
#   'https://sales.org/sales/ontology#familyDescription': {'domain': 'https://sales.org/sales/ontology#ProductFamily',
#    'range': 'http://www.w3.org/2001/XMLSchema#string'}},
#  'raw_result': {'head': {'vars': ['s', 'p', 'o']},
#   'results': {'bindings': [{'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#Customer'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#CustomerContact'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#CustomerAddress'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#Order'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#Sale'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#SalesPayment'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#SalesDiscountTax'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#SalesFulfillment'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#Product'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#Inventory'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#Supplier'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductBrand'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductType'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductLine'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductClass'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductFamily'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductDetail'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#gender'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#age'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#email'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#phone'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasContact'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isContactOf'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#address'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#city'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#state'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#country'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#customerId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#contactId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#addressId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#orderId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#saleId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#inventoryId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#supplierId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#brandId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#typeId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#lineId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#classId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#familyId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#skuId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#customerName'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#registrationDate'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isActive'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#addressType'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#postalCode'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#orderDate'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#orderStatus'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#quantity'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#price'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#totalAmount'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#saleDate'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#netAmount'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#paymentMethod'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#paymentStatus'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#invoiceNumber'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#transactionId'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#discountValue'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#discountPercent'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#taxAmount'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#shippingCharges'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#fulfillmentStatus'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#returnReason'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#refundStatus'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasAddress'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isAddressOf'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasOrder'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#orderedBy'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#hasSale'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#saleFromOrder'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasPayment'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isPaymentFor'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasDiscountDetail'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isDiscountOf'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasFulfillment'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isFulfillmentFor'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasInventory'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isInventoryOf'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#location'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#quantityOnHand'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#reorderLevel'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#reorderQuantity'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#safetyStockLevel'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#lastRestockDate'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#supplierName'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#contactName'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#supplierEmail'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#supplierPhone'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#supplierAddress'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#      'o': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#DatatypeProperty'}},
#     {'s': {'type': 'uri',
# ...
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#customerId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-11'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#contactId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-12'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#addressId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-13'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#orderId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-14'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#saleId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-15'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#productId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-16'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#inventoryId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-17'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#supplierId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-18'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#brandId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-19'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#typeId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-110'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#lineId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-111'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#classId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-112'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#familyId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-113'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#onProperty'},
#      'o': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#skuId'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-10'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-11'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-12'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-13'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-14'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-15'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-16'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-17'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-18'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-19'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-110'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-111'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-112'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-113'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#maxCardinality'},
#      'o': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#       'type': 'literal',
#       'value': '1'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#Customer'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-10'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#CustomerContact'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-11'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#CustomerAddress'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-12'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#Order'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-13'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#Sale'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-14'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology#Product'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-15'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#Inventory'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-16'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#Supplier'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-17'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductBrand'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-18'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductType'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-19'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductLine'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-110'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductClass'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-111'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductFamily'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-112'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#ProductDetail'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#      'o': {'type': 'bnode',
#       'value': 'anon-genid-feda09fa7a21413391c7cb8cbdb4684f-113'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isContactOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasContact'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isAddressOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasAddress'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#orderedBy'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasOrder'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#saleFromOrder'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasSale'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isPaymentFor'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasPayment'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isDiscountOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasDiscountDetail'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isFulfillmentFor'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasFulfillment'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isInventoryOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasInventory'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#productOrderedIn'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#orderedProduct'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isDetailOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasDetail'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isBrandOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasBrand'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isTypeOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasType'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isLineOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasLine'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isClassOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasClass'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isFamilyOf'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasFamily'}},
#     {'s': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#isSupplierFor'},
#      'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#      'o': {'type': 'uri',
#       'value': 'https://sales.org/sales/ontology#hasSupplier'}},
#     {'s': {'type': 'uri', 'value': 'https://sales.org/sales/ontology'},
#      'p': {'type': 'uri',
#       'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#      'o': {'type': 'literal', 'value': '2'}}]}}}
